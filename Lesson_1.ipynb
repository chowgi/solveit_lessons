# %%
from aocd import get_data
data = get_data(day=1, year=2023)
data[:30]
# Out:
# 'eightqrssm9httwogqshfxninepnfr'

# %% [markdown]
# ## Problem
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
#
# ```
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# ```
#
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.

# %% [markdown]
# **AI Prompt**
#
# help me split data the based on line break into a list and then display the list

# %% [markdown]
# **AI Response**
#
# I can help you with that! To split the data by line breaks, we can use the `split()` method. Would you like to try writing the code yourself first, or would you like me to show you how?

# %% [markdown]
# **AI Prompt**
#
# show me how please?

# %% [markdown]
# **AI Response**
#
# Here's how to split the data into lines:
#
# ```python
# lines = data.split('\n')
# print(lines[:5])  # This will show the first 5 lines
# ```
#
# This splits the data at each newline character (`\n`). I'm showing just the first 5 lines to keep the output manageable. Would you like to run this and see how it looks?

# %%
lines = data.split('\n')
print(lines[:5])  # This will show the first 5 lines
# Out:
# ['eightqrssm9httwogqshfxninepnfrppfzhsc', 'one111jxlmc7tvklrmhdpsix', 'bptwone4sixzzppg', 'ninezfzseveneight5kjrjvtfjqt5nineone', '58kk']

# %% [markdown]
# Addings sample data for testing

# %%
samp = ```1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet
```
# Out:
#   Cell In[1], line 1
#     samp = ```1abc2
#               ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **AI Prompt**
#
# help me fix the samp variable. I want it to remain a string

# %% [markdown]
# **AI Response**
#
# To create a multi-line string in Python, we can use triple quotes. Here's the correct way to create the sample data:
#
# ```python
# samp = """1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet"""
# ```
#
# Would you like to try running this? Then we can split it into lines just like we did with the previous data.

# %%
samp = """1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet
"""

# %%
samp_lines = samp.split('\n')
samp_lines
# Out:
# ['1abc2', 'pqr3stu8vwx', 'a1b2c3d4e5f', 'treb7uchet', '']

# %% [markdown]
# **AI Prompt**
#
# I need to find the first and and last digit for eaach item in the list. How would I code that?

# %% [markdown]
# **AI Response**
#
# Let's break this down into steps:
#
# 1. First, would you like to try writing a function that finds digits in a single string? We could start with something that looks through each character and checks if it's a digit.
#
# Here's a small example to get you thinking:
# ```python
# test_string = "1abc2"
# # How could we find the first and last digits in this string?
# ```
#
# Would you like to try writing some code for this first step, or would you like more guidance?

# %% [markdown]
# **AI Prompt**
#
# guidance please

# %% [markdown]
# **AI Response**
#
# Let's solve this step by step. First, we can use Python's built-in `isdigit()` method to check if a character is a digit.
#
# Here's one way to find digits in a string:
# ```python
# test_string = "1abc2"
# digits = [char for char in test_string if char.isdigit()]
# print(digits)  # This will show all digits found
# ```
#
# Try running this code. What do you think it will output? After you see the result, we can work on getting just the first and last digits.

# %%
test_string = "1abc2"
digits = [char for char in test_string if char.isdigit()]
print(digits)  # This will show all digits found
# Out:
# ['1', '2']

# %% [markdown]
# **AI Prompt**
#
# okay now combine them into a single int

# %% [markdown]
# **AI Response**
#
# To combine the first and last digits into a single integer, we can use string concatenation and then convert to an int. Here's how:
#
# ```python
# first_digit = digits[0]    # Get first digit
# last_digit = digits[-1]    # Get last digit
# number = int(first_digit + last_digit)  # Combine and convert to integer
# print(number)
# ```
#
# Try running this code. What result do you expect to get from our test string "1abc2"?

# %%
first_digit = digits[0]    # Get first digit
last_digit = digits[-1]    # Get last digit
number = int(first_digit + last_digit)  # Combine and convert to integer
print(number)
# Out:
# 12

# %% [markdown]
# **AI Prompt**
#
# okay now we need a function that takes in a list and adds each number to a new list.

# %% [markdown]
# **AI Response**
#
# Let's create a function that processes each line and collects all the numbers. Would you like to try writing this function yourself first?
#
# You can use what we just learned to process each line. The function would need to:
# 1. Take a list of strings as input
# 2. Process each string like we did above
# 3. Store the numbers in a new list
#
# Would you like to try writing it, or would you like me to show you how?

# %% [markdown]
# **AI Prompt**
#
# show me please

# %% [markdown]
# **AI Response**
#
# Here's a function that processes the list:
#
# ```python
# def process_lines(lines):
#     numbers = []
#     for line in lines:
#         # Get digits from the line
#         digits = [char for char in line if char.isdigit()]
#         if digits:  # Make sure we found some digits
#             # Combine first and last digit
#             number = int(digits[0] + digits[-1])
#             numbers.append(number)
#     return numbers
#
# # Let's test it with our sample data
# result = process_lines(samp_lines)
# print(result)
# ```
#
# Let's run this and see what numbers we get. Does the output match what you'd expect from our sample data?

# %%
def process_lines(lines):
    numbers = []
    for line in lines:
        # Get digits from the line
        digits = [char for char in line if char.isdigit()]
        if digits:  # Make sure we found some digits
            # Combine first and last digit
            number = int(digits[0] + digits[-1])
            numbers.append(number)
    return numbers

# Let's test it with our sample data
result = process_lines(samp_lines)
print(result)
# Out:
# [12, 38, 15, 77]

# %% [markdown]
# **AI Prompt**
#
# okay now it needs to sum the total and return the total rather than the list

# %% [markdown]
# **AI Response**
#
# We can modify the function to sum the numbers instead of returning the list. Would you like to try adding this yourself, or would you like me to show you how to modify the code?
#
# One hint: Python has a built-in `sum()` function that can add up all numbers in a list.
#
# What would you prefer?

# %%
result
# Out:
# [12, 38, 15, 77]

# %%
sum(result)
# Out:
# 142

# %%
def solve_1a(lines):
    numbers = []
    for line in lines:
        # Get digits from the line
        digits = [char for char in line if char.isdigit()]
        if digits:  # Make sure we found some digits
            # Combine first and last digit
            number = int(digits[0] + digits[-1])
            numbers.append(number)
    
    result = sum(numbers)
    return result

# %%
# Make sure it works with sample data
solve_1a(samp_lines)
# Out:
# 142

# %%
# Make sure it works with real data
solve_1a(lines)
# Out:
# 54159

# %% [markdown]
# ## --- Part Two ---
# Your calculation isn't quite right. It looks like some of the digits are actually spelled out with letters: one, two, three, four, five, six, seven, eight, and nine also count as valid "digits".
#
# Equipped with this new information, you now need to find the real first and last digit on each line. For example:
# ```
# two1nine
# eightwothree
# abcone2threexyz
# xtwone3four
# 4nineeightseven2
# zoneight234
# 7pqrstsixteen
# ```
# In this example, the calibration values are 29, 83, 13, 24, 42, 14, and 76. Adding these together produces 281.

# %% [markdown]
# **AI Prompt**
#
# Okay so we have new information. the stings in each item in the list might have the number spelled out eg. 8 could be 'eight'. The first step would eb to identify the numbers in the list. How would I code that.

# %% [markdown]
# **AI Response**
#
# Let's start by creating a dictionary that maps spelled-out numbers to their digit equivalents. Here's a first step:
#
# ```python
# number_words = {
#     'one': '1', 'two': '2', 'three': '3', 'four': '4',
#     'five': '5', 'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
# }
# ```
#
# Would you like to test this with a single line first to see how we might find these words in a string? We could try with one of the example strings like "two1nine" to experiment.
#
# What would you like to try first?

# %%
number_words = {
    'one': '1', 'two': '2', 'three': '3', 'four': '4',
    'five': '5', 'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
}

# %% [markdown]
# **AI Prompt**
#
# yes lets try that

# %% [markdown]
# **AI Response**
#
# Let's test with a simple example string. We'll need to check both for regular digits and spelled-out numbers. Here's a test string:
#
# ```python
# test_string = "two1nine"
#
# # Let's first try to find all the number words in this string
# for word in number_words:
#     if word in test_string:
#         print(f"Found {word} = {number_words[word]}")
# ```
#
# Run this and see what it finds. Then we can think about how to handle both digits and words together. What do you think the output will be?

# %%
test_string = "two1nine"

# Let's first try to find all the number words in this string
for word in number_words:
    if word in test_string:
        print(f"Found {word} = {number_words[word]}")
# Out:
# Found two = 2
# Found nine = 9

# %% [markdown]
# **AI Prompt**
#
# okay so we need a way to loop through each string and identify in order all the numbers and output to a list of integers

# %% [markdown]
# **AI Response**
#
# To find numbers in order, we'll need to track their positions in the string. Here's one way we could start:
#
# ```python
# test_string = "two1nine"
# found_numbers = []
#
# # Let's find positions of both words and digits
# for i, char in enumerate(test_string):
#     # Check for digits
#     if char.isdigit():
#         found_numbers.append((i, char))
#
#     # Check for number words starting at this position
#     for word, digit in number_words.items():
#         if test_string[i:].startswith(word):
#             found_numbers.append((i, digit))
#
# print(found_numbers)
# ```
#
# Try running this code. What do you notice about the output? Does it give us what we need to solve the problem?

# %%
test_string = "two1nine"
found_numbers = []

# Let's find positions of both words and digits
for i, char in enumerate(test_string):
    # Check for digits
    if char.isdigit():
        found_numbers.append((i, char))
    
    # Check for number words starting at this position
    for word, digit in number_words.items():
        if test_string[i:].startswith(word):
            found_numbers.append((i, digit))

print(found_numbers)
# Out:
# [(0, '2'), (3, '1'), (4, '9')]

# %% [markdown]
# **AI Prompt**
#
# I notice it outputs a list of tuples. Explaine the code line by line on how this works

# %% [markdown]
# **AI Response**
#
# Let's break down each line:
#
# 1. `test_string = "two1nine"`
#    - Creates our test string
#
# 2. `found_numbers = []`
#    - Creates an empty list to store our results
#
# 3. `for i, char in enumerate(test_string):`
#    - `enumerate()` gives us both the position (i) and character (char) for each character in the string
#    - For example, in "two1nine": (0,'t'), (1,'w'), (2,'o'), (3,'1'), etc.
#
# 4. `if char.isdigit():`
#    - Checks if the current character is a number
#    - If it is, adds its position and the digit to found_numbers as a tuple
#
# 5. `for word, digit in number_words.items():`
#    - Loops through our dictionary of number words
#    - `word` would be 'one', 'two', etc.
#    - `digit` would be '1', '2', etc.
#
# 6. `if test_string[i:].startswith(word):`
#    - `test_string[i:]` takes a slice of the string starting at position i
#    - `startswith(word)` checks if that slice begins with our number word
#    - For example, when i=0, checks if "two1nine" starts with any number word
#
# 7. `found_numbers.append((i, digit))`
#    - If a match is found, adds the position and the digit as a tuple
#
# Would you like me to show you what the code finds at each step with a specific example?

# %% [markdown]
# **AI Prompt**
#
# yes please

# %% [markdown]
# **AI Response**
#
# Let's add some print statements to see what happens at each step with "two1nine":
#
# ```python
# test_string = "two1nine"
# found_numbers = []
#
# # Let's find positions of both words and digits
# for i, char in enumerate(test_string):
#     print(f"\nChecking position {i}, character '{char}':")
#
#     # Check for digits
#     if char.isdigit():
#         print(f"Found digit: {char}")
#         found_numbers.append((i, char))
#
#     # Check for number words starting at this position
#     print(f"Checking if any number words start at position {i}: {test_string[i:]}")
#     for word, digit in number_words.items():
#         if test_string[i:].startswith(word):
#             print(f"Found word: {word} = {digit}")
#             found_numbers.append((i, digit))
#
# print("\nFinal list:", found_numbers)
# ```
#
# Let's run this and see what it finds at each position. Would you like to try it?

# %%
test_string = "two1nine"
found_numbers = []

# Let's find positions of both words and digits
for i, char in enumerate(test_string):
    print(f"\nChecking position {i}, character '{char}':")
    
    # Check for digits
    if char.isdigit():
        print(f"Found digit: {char}")
        found_numbers.append((i, char))
    
    # Check for number words starting at this position
    print(f"Checking if any number words start at position {i}: {test_string[i:]}")
    for word, digit in number_words.items():
        if test_string[i:].startswith(word):
            print(f"Found word: {word} = {digit}")
            found_numbers.append((i, digit))

print("\nFinal list:", found_numbers)
# Out:
# Checking position 0, character 't':
# Checking if any number words start at position 0: two1nine
# Found word: two = 2
#
# Checking position 1, character 'w':
# Checking if any number words start at position 1: wo1nine
#
# Checking position 2, character 'o':
# Checking if any number words start at position 2: o1nine
#
# Checking position 3, character '1':
# Found digit: 1
# Checking if any number words start at position 3: 1nine
#
# Checking position 4, character 'n':
# Checking if any number words start at position 4: nine
# Found word: nine = 9
#
# Checking position 5, character 'i':
# Checking if any number words start at position 5: ine
#
# Checking position 6, character 'n':
# Checking if any number words start at position 6: ne
#
# Checking position 7, character 'e':
# Checking if any number words start at position 7: e
#
# Final list: [(0, '2'), (3, '1'), (4, '9')]

# %% [markdown]
# **AI Prompt**
#
# cool thankyou. Lets make that a function. Show me the code.

# %% [markdown]
# **AI Response**
#
# Here's how we can turn this into a function:
#
# ```python
# def find_numbers_in_string(input_string):
#     found_numbers = []
#
#     # Find positions of both words and digits
#     for i, char in enumerate(input_string):
#         # Check for digits
#         if char.isdigit():
#             found_numbers.append((i, char))
#
#         # Check for number words starting at this position
#         for word, digit in number_words.items():
#             if input_string[i:].startswith(word):
#                 found_numbers.append((i, digit))
#
#     # Sort by position (first element of tuple)
#     found_numbers.sort(key=lambda x: x[0])
#     return found_numbers
#
# # Let's test it
# test_string = "two1nine"
# result = find_numbers_in_string(test_string)
# print(result)
# ```
#
# Would you like to try it with different test strings? We could test it with some of the other example cases to make sure it works correctly.

# %%
def find_numbers_in_string(input_string):
    found_numbers = []
    
    # Find positions of both words and digits
    for i, char in enumerate(input_string):
        # Check for digits
        if char.isdigit():
            found_numbers.append((i, char))
        
        # Check for number words starting at this position
        for word, digit in number_words.items():
            if input_string[i:].startswith(word):
                found_numbers.append((i, digit))
    
    # Sort by position (first element of tuple)
    found_numbers.sort(key=lambda x: x[0])
    return found_numbers

# Let's test it
test_string = "two1nine"
result = find_numbers_in_string(test_string)
print(result)
# Out:
# [(0, '2'), (3, '1'), (4, '9')]

# %% [markdown]
# **AI Prompt**
#
# Now lets create a function that combines the first and last numbers. Show me the code.

# %% [markdown]
# **AI Response**
#
# Here's a function that takes the list of found numbers and combines the first and last digits:
#
# ```python
# def combine_first_last(found_numbers):
#     if not found_numbers:  # Check if list is empty
#         return None
#
#     # Get first and last digits
#     first_digit = found_numbers[0][1]    # Second element of first tuple
#     last_digit = found_numbers[-1][1]    # Second element of last tuple
#
#     # Combine and convert to integer
#     return int(first_digit + last_digit)
#
# # Let's test both functions together
# test_string = "two1nine"
# numbers = find_numbers_in_string(test_string)
# result = combine_first_last(numbers)
# print(f"String: {test_string}")
# print(f"Found numbers: {numbers}")
# print(f"Combined result: {result}")
# ```
#
# Would you like to try this with some test cases to see if it works as expected?

# %%
def combine_first_last(found_numbers):
    if not found_numbers:  # Check if list is empty
        return None
    
    # Get first and last digits
    first_digit = found_numbers[0][1]    # Second element of first tuple
    last_digit = found_numbers[-1][1]    # Second element of last tuple
    
    # Combine and convert to integer
    return int(first_digit + last_digit)

# Let's test both functions together
test_string = "two1nine"
numbers = find_numbers_in_string(test_string)
result = combine_first_last(numbers)
print(f"String: {test_string}")
print(f"Found numbers: {numbers}")
print(f"Combined result: {result}")
# Out:
# String: two1nine
# Found numbers: [(0, '2'), (3, '1'), (4, '9')]
# Combined result: 29

# %% [markdown]
# **AI Prompt**
#
# okay now we need a wrapper function to take in a list of items. It should lopp through each item and:
# 1. Look for number using the find_numbers_in_string function
# 2. combine the first and last using combine_first_last
# 3. Add the result to a new list

# %% [markdown]
# **AI Response**
#
# Here's how we can create a wrapper function that processes a list of strings:
#
# ```python
# def process_all_lines(lines):
#     results = []
#     for line in lines:
#         # Find all numbers in the line
#         numbers = find_numbers_in_string(line)
#         # Combine first and last
#         value = combine_first_last(numbers)
#         # Add to results
#         if value is not None:
#             results.append(value)
#     return results
#
# # Let's test it with a few example strings
# test_lines = [
#     "two1nine",
#     "eightwothree",
#     "abcone2threexyz"
# ]
# values = process_all_lines(test_lines)
# print("Individual values:", values)
# print("Sum of all values:", sum(values))
# ```
#
# Would you like to try this with the test cases to make sure it works correctly?

# %%
def process_all_lines(lines):
    results = []
    for line in lines:
        # Find all numbers in the line
        numbers = find_numbers_in_string(line)
        # Combine first and last
        value = combine_first_last(numbers)
        # Add to results
        if value is not None:
            results.append(value)
    return results

# Let's test it with a few example strings
test_lines = [
    "two1nine",
    "eightwothree",
    "abcone2threexyz"
]
values = process_all_lines(test_lines)
print("Individual values:", values)
print("Sum of all values:", sum(values))
# Out:
# Individual values: [29, 83, 13]
# Sum of all values: 125

# %%
def solve_1b(lines):
    results = []
    for line in lines:
        # Find all numbers in the line
        numbers = find_numbers_in_string(line)
        # Combine first and last
        value = combine_first_last(numbers)
        # Add to results
        if value is not None:
            results.append(value)
    return results

# %%
samp_1b = """two1nine
eightwothree
abcone2threexyz
xtwone3four
4nineeightseven2
zoneight234
7pqrstsixteen"""

samp_lines_1b = samp_1b.split('\n')
samp_lines_1b
# Out:
# ['two1nine',
#  'eightwothree',
#  'abcone2threexyz',
#  'xtwone3four',
#  '4nineeightseven2',
#  'zoneight234',
#  '7pqrstsixteen']

# %%
sum(solve_1b(samp_lines_1b))
# Out:
# 281

# %%
sum(solve_1b(lines))
# Out:
# 53866
